# %% [markdown]
# Make sure the runtime is in GPU.
# Run following cells to connect to repository containing models.

# %%
# !ssh-keygen -t rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !clear
# !echo "PUBLIC KEY: (for github.com)"
# !cat /root/.ssh/id_rsa.pub
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:PfqR4/Jt8Bw7Npe4QVQYpMIxmsRIKC8em+sOPJojKAI root@b24417b44f4b
# The key's randomart image is:
# +---[RSA 3072]----+
# |   o.o. o  .oo.  |
# |. . ...+ o ...   |
# | o    o o . .    |
# |...      o .     |
# |..+     S o .    |
# |E+       ..+.    |
# |+o.     . ++.+ . |
# |Oo.     .o +X.o  |
# |O+       o+oo=   |
# +----[SHA256]-----+
# # github.com:22 SSH-2.0-0264bb16
# PUBLIC KEY: (for github.com)
# ssh-rsa ... root@b24417b44f4b

# %% [markdown]
# Follow these steps before proceeding:
#
# Go to https://github.com/settings/keys and login if necessary
# Click the green "New SSH Key" button
# Choose any title
# From the cell above in this Colab notebook, copy the public key. It looks like "ssh-rsa xxxxx", is very long, and should be the last line.
# Paste the key into the "key" text box and click "Add SSH key"
# Below, replace [GITHUBUSERNAME] with your GitHub username.
# Run the cell.

# %%
# !git clone git@github.com:melyssa5/style-scape.git
# %cd style-scape

# !git config --global user.email "colab_bot@brown.edu"
# !git config --global user.name "Colab Bot"
# Out:
# Cloning into 'style-scape'...
# remote: Enumerating objects: 11131, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 11131 (delta 84), reused 82 (delta 36), pack-reused 10998 (from 1)
# Receiving objects: 100% (11131/11131), 465.50 MiB | 55.65 MiB/s, done.
# Resolving deltas: 100% (395/395), done.
# Updating files: 100% (9050/9050), done.
# /content/style-scape

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 757 bytes | 757.00 KiB/s, done.
# From github.com:melyssa5/style-scape
#    c6fe2a4..4930b56  limes      -> origin/limes
# Updating c6fe2a4..4930b56
# Fast-forward
#  code/models/restnet50.py | 38 ++++++++++++++++++--------------------
#  1 file changed, 18 insertions(+), 20 deletions(-)

# %% [markdown]
# %ls -a

# %%
# %cd code/models
# Out:
# /content/style-scape/code/models

# %% [markdown]
# Run model script.

# %%
# !python restnet50.py
# Out:
# 2025-05-12 07:49:12.372586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747036152.396026   36033 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747036152.402980   36033 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12 07:49:12.425925: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !git add clip_gradcam_outputs_natural/
# !git commit -m "pushing more clip images colab"
# !git push
# Out:
# [main c319035] pushing more clip images colab
#  5 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 code/models/clip_gradcam_outputs_natural/clip_cam_0_class_2.png
#  create mode 100644 code/models/clip_gradcam_outputs_natural/clip_cam_1_class_2.png
#  create mode 100644 code/models/clip_gradcam_outputs_natural/clip_cam_2_class_2.png
#  create mode 100644 code/models/clip_gradcam_outputs_natural/clip_cam_3_class_2.png
#  create mode 100644 code/models/clip_gradcam_outputs_natural/clip_cam_4_class_2.png
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 302.47 KiB | 1.36 MiB/s, done.
# Total 10 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:melyssa5/style-scape.git
#    4aa68fe..c319035  main -> main
